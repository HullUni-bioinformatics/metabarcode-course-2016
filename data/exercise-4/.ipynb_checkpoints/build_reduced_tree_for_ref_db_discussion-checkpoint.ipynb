# %%
from reprophylo import *

# %%
pj = Project('./input_data/target_locus.csv', pickle='reduced_tree.pkl', git=False)
# Out:
# DEBUG:Cloud:Log file (/root/.picloud/cloud.log) opened

# %%
pj.read_embl_genbank(['./input_data/CytB_nr_pre_Sativa.gb'])
# Out:
# /home/reprophylo/reprophylo.py:1015: UserWarning: Version control off
#   warnings.warn('Version control off')

# %%
pj.extract_by_locus()

# %%
# %matplotlib inline
pj.report_seq_stats()
# Out:
# Distribution Of Sequence Lengths
# Distribution Of Sequence Statistic "Gc_Content"
# /usr/lib/pymodules/python2.7/matplotlib/figure.py:371: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %% [markdown]
# Collect all record ids in a list.

# %%
full_id_list = []
for r in pj.records:
    full_id_list.append(r.id)
    
print len(full_id_list)
# Out:
# 1760

# %% [markdown]
# Find the ids of the records which are mislabelled according to SATIVA.

# %%
rec_mislabelled = {}
sativa=open('./input_data/CytB.mis', 'r')

for line in sativa:
    if not line.startswith(";"):
        rec_mislabelled[line.split("\t")[0]] = line.split("\t")[4]

# %%
print rec_mislabelled
# Out:
# {'EU492281.1': '0.989', 'EU224046.1': '0.838', 'AJ969128.1': '0.999', 'AJ937943.1': '0.868', 'JF489783.1': '1.000', 'KT275288.1': '0.994', 'DQ185405.1': '1.000', 'KT275289.1': '0.998', 'EU224045.1': '0.819', 'JQ346141.1': '1.000', 'JQ661401.1': '1.000', 'AJ937931.1': '0.922', 'AJ937952.1': '0.791', 'AJ937925.1': '0.999', 'JQ661398.1': '0.973', 'AJ937951.1': '0.792', 'KP644340.1': '1.000', 'DQ664351.1': '0.587', 'GQ279764.1': '0.625', 'GU182336.1': '0.920', 'JQ661399.1': '0.974', 'KP452507.1': '0.508', 'JQ661400.1': '0.973', 'JQ231114.1': '1.000'}

# %% [markdown]
# Exclude the record ids that have been identified as mislabelled from the total list of ids.

# %%
pool = []

for i in full_id_list:
    if not i in rec_mislabelled.keys():
        pool.append(i)
        
print len(pool)
# Out:
# 1736

# %% [markdown]
# Bin records by species.

# %%
species={}
count = 0
for r in pj.records:
    if r.id in pool:
        count+=1
        source = [f for f in r.features if f.type == 'source'][0]
        if not " ".join(source.qualifiers['organism'][0].split()[0:2]) in species:
            species[" ".join(source.qualifiers['organism'][0].split()[0:2])] = []
        species[" ".join(source.qualifiers['organism'][0].split()[0:2])].append(r.id)
        
total=len(species)

print "Total number of records: %i" %count
print "Number of species (see below for full list): %i" %len(species)
print species
# Out:
# Total number of records: 1736
# Number of species (see below for full list): 65
# {'Rutilus rutilus': ['HM156755.1', 'KR025542.1', 'KF784831.1', 'KR025541.1', 'HM156754.1', 'KF784838.1', 'HM156756.1', 'HM156757.1', 'HM560167.1', 'KU302643.1', 'HM156752.1', 'KF552102.1', 'KF784839.1', 'HM156758.1', 'HM560168.1', 'KF784812.1', 'HM156751.1', 'KF784813.1', 'KF784821.1', 'KF784820.1', 'FJ025074.1', 'HM156753.1', 'KF784833.1', 'KF784808.1', 'KF784819.1', 'KF784822.1', 'KF784815.1', 'FJ025072.1', 'KF784841.1', 'KF784814.1', 'KF784810.1', 'KF784840.1', 'KC696559.1', 'AJ555554.1', 'FJ025068.1', 'KF784811.1', 'KF784832.1', 'HM156759.1', 'FJ025078.1'], 'Proterorhinus semilunaris': ['EU444660.1', 'KJ605205.1', 'EU444650.1', 'KJ605209.1', 'EU444627.1', 'KJ605212.1', 'KJ605203.1', 'KJ605198.1', 'KJ605207.1', 'KJ605194.1', 'EU444609.1', 'EU444633.1', 'KJ605192.1', 'EU444613.1', 'EU444659.1', 'EU444649.1', 'EU444661.1', 'KJ605206.1', 'EU444651.1', 'EU444605.1', 'EU444607.1', 'KJ605208.1', 'EU444665.1', 'KJ605204.1', 'KJ605196.1', 'EU444625.1', 'KJ605200.1', 'EU444663.1', 'KJ605202.1', 'EU444662.1', 'EU444626.1', 'KJ605210.1', 'EU444608.1', 'KJ605211.1', 'KJ605199.1', 'EU444604.1', 'EU444606.1', 'KJ605191.1', 'KJ605201.1', 'EU444632.1', 'KJ605193.1', 'EU444634.1', 'EU444664.1', 'EU444612.1', 'EU444658.1', 'KJ605197.1', 'EU444628.1'], 'Salmo salar': ['EU492280.1', 'JQ390055.1', 'BT044011.1', 'AF133701.1', 'JX960833.1', 'FJ435619.1', 'JQ390056.1'], 'Gymnocephalus cernua': ['KC819833.1', 'KM978956.1', 'AF045356.1'], 'Leuciscus leuciscus': ['DQ664318.1', 'DQ664329.1', 'DQ664348.1', 'DQ664422.1', 'DQ664377.1', 'DQ664340.1', 'DQ664424.1', 'DQ664435.1', 'KR025548.1', 'DQ664418.1', 'DQ664369.1', 'DQ664309.1', 'DQ664437.1', 'DQ664357.1', 'DQ664398.1', 'DQ664308.1', 'DQ664428.1', 'DQ664409.1', 'DQ664302.1', 'DQ664371.1', 'HM560100.1', 'DQ664374.1', 'DQ664365.1', 'DQ664366.1', 'DQ664362.1', 'AJ555553.1', 'DQ664353.1', 'DQ664306.1', 'DQ664389.1', 'DQ664391.1', 'DQ664349.1', 'KR025547.1', 'DQ664322.1', 'DQ664382.1', 'DQ664361.1', 'DQ664315.1', 'DQ664438.1', 'DQ664341.1', 'DQ664380.1', 'DQ664317.1', 'DQ664406.1', 'DQ664378.1', 'DQ664324.1', 'DQ664331.1', 'DQ664342.1', 'DQ664304.1', 'DQ664355.1', 'DQ664395.1', 'DQ664336.1', 'DQ664326.1', 'DQ664419.1', 'DQ664432.1', 'DQ664359.1', 'DQ664356.1', 'DQ664412.1', 'DQ664372.1', 'DQ664386.1', 'DQ664407.1', 'DQ664410.1', 'DQ664303.1', 'DQ664370.1', 'DQ664400.1', 'DQ664401.1', 'DQ664429.1', 'DQ664376.1', 'DQ664313.1', 'DQ664350.1', 'DQ664320.1', 'DQ664394.1', 'DQ664446.1', 'DQ664421.1', 'DQ664323.1', 'DQ664441.1', 'DQ664346.1', 'DQ664347.1', 'DQ664445.1', 'DQ664439.1', 'DQ664383.1', 'DQ664314.1', 'DQ664397.1', 'DQ664396.1', 'DQ664352.1', 'DQ664414.1', 'DQ664343.1', 'DQ664305.1', 'DQ664328.1', 'DQ664316.1', 'DQ664354.1', 'DQ664444.1', 'DQ664393.1', 'DQ664333.1', 'DQ664310.1', 'DQ664433.1', 'DQ664375.1', 'DQ664425.1', 'DQ664381.1', 'DQ664358.1', 'DQ664430.1', 'DQ664387.1', 'DQ664408.1', 'DQ664339.1', 'DQ664338.1', 'DQ664390.1', 'DQ664360.1', 'DQ664327.1', 'DQ664403.1', 'DQ664312.1', 'DQ664384.1', 'DQ664321.1', 'DQ664443.1', 'DQ664420.1', 'DQ664319.1', 'DQ664411.1', 'DQ664413.1', 'DQ664330.1', 'DQ664417.1', 'DQ664404.1', 'HM560101.1', 'DQ664415.1', 'DQ664385.1', 'DQ664337.1', 'DQ664368.1', 'DQ664440.1', 'AY509823.1', 'DQ664332.1', 'DQ664367.1', 'DQ664436.1', 'DQ664363.1', 'DQ664399.1', 'DQ664405.1', 'DQ664426.1', 'DQ664416.1', 'DQ664434.1', 'DQ664431.1', 'DQ664392.1', 'DQ664307.1', 'DQ664427.1', 'DQ664402.1', 'DQ664335.1', 'DQ664334.1', 'DQ664388.1', 'DQ664379.1', 'DQ664423.1', 'DQ664442.1'], 'Lota lota': ['AY226384.1', 'AY226398.1', 'KU316025.1', 'AY226395.1', 'AY226410.1', 'NC_004379.1', 'AY226388.1', 'KM363244.1', 'AY226408.1', 'KM201364.1', 'AY226406.1', 'AY226405.1', 'KU316022.1', 'AY226383.1', 'KU316024.1', 'AY226409.1', 'AY226394.1', 'KT327178.1', 'AY226404.1', 'KC844053.1', 'EF191376.1', 'DQ174052.1', 'AY226403.1', 'AY226407.1', 'AY226386.1', 'DQ174053.1', 'AY226399.1'], 'Phoxinus phoxinus': ['NC_020358.1', 'KC992395.1', 'KC906398.1'], 'Thymallus thymallus': ['FJ853655.1', 'JX960869.1', 'JX9608 ...

# %% [markdown]
# For every species extract at most a total of 5 record ids.

# %%
import random

to_keep = []
for sp in species:
#    print sp
#    print len(species[sp])
    if len(species[sp]) > 5:
        to_keep.extend(random.sample(species[sp], 5))
    else:
        to_keep.extend(species[sp])
        

print len(to_keep)
# Out:
# 274

# %% [markdown]
# Remove _Petromyzon marinus_ (Genbank accession: NC_001626.1) from the list of focal records for aesthetic reasons.

# %%
for i in range(len(to_keep)):
    if 'NC_001626.1' == to_keep[i]:
        del to_keep[i]
        break
print len(to_keep)
# Out:
# 273

# %% [markdown]
# Add the mislabelled ids to the list.

# %%
to_keep.extend(rec_mislabelled.keys())
print len(to_keep)
# Out:
# 297

# %%
to_drop = {'CytB': []}

for s in full_id_list:
    if not s in to_keep:
        to_drop['CytB'].append(s)

print len(to_drop['CytB'])
# Out:
# 1463

# %% [markdown]
# Exclude records from data set.

# %%
pj.exclude(start_from_max=False, **to_drop)

# %% [markdown]
# Configure alignment object.

# %%
mafft_linsi = AlnConf(pj,                              # The Project
                    method_name='mafftLinsi',        # Any unique method name,
                    CDSAlign=True,                   # Use this method to align
                    codontable=2,                    # The genetic code that
                    program_name='mafft',            # mafft or muscle.
                    cmd='mafft',                     # The command on your machine
                    loci=['CytB'],                 # A list of loci names to align.vel.
                    cline_args={'localpair': True,# Program specific keywords and arguments.
                                'maxiterate': 1000}# cine_args=={} by default, which will
                    )
# Out:
# mafft --localpair --maxiterate 1000 947691473684275.81_CDS_proteins_CytB.fasta

# %% [markdown]
# Perform alignment.

# %%
pj.align([mafft_linsi])

# %%
pj.write_alns(id=['record_id','source_organism'], format='fasta')
# Out:
# ['CytB@mafftLinsi_aln.fasta']

# %% [markdown]
# Determine custom clipping points in alignment.

# %%
import numpy as np

per_col=[]

aln = pj.fa('CytB@mafftLinsi')


icol=0
for a in aln[1,:]:
    ACGT_count=0
    col=aln[:,icol]
    for i in range(len(col)):
        if col[i] in ['A','G','C','T']:
            ACGT_count+=1
#    print pj.fa('CytB@mafftLinsi')[:,a]
    per_col.append(float(ACGT_count)/len(col))
    icol+=1

wsize=10
min_prop=0.7
    
print "\nFinding forward clip position:\n"
forw_count=0
forw_clip=0
for i in range(len(per_col)-wsize):
        
    if np.mean(per_col[i:i+10]) > min_prop:
        forw_count+=1
        forw_clip=i
        print forw_count,i,np.mean(per_col[i:i+wsize])
    else:
        forw_count=0
        
    if forw_count >= wsize:
        break
        
print "Suggested forward clip at: %s (%s,%s)" %(forw_clip-wsize,forw_count,forw_clip)

print "\nFinding reverse clip position:\n"
reve_count=0
reve_clip=0
for i in reversed(range(len(per_col)-wsize)):
        
    if np.mean(per_col[i:i+10]) > min_prop:
        reve_count+=1
        reve_clip=i
        print reve_count,i,np.mean(per_col[i:i+wsize])
    else:
        reve_count=0
        
    if reve_count >= wsize:
        break
    
print "Suggested reverse clip at: %s (%s,%s)" %(reve_clip+wsize,reve_count,reve_clip)
# Out:
# returning alignment object CytB@mafftLinsi
#
# Finding forward clip position:
#
# 1 27 0.767003367003
# 2 28 0.775757575758
# 3 29 0.784511784512
# 4 30 0.795286195286
# 5 31 0.803367003367
# 6 32 0.811447811448
# 7 33 0.821212121212
# 8 34 0.828282828283
# 9 35 0.835353535354
# 10 36 0.842424242424
# Suggested forward clip at: 26 (10,36)
#
# Finding reverse clip position:
#
# 1 1147 0.70202020202
# 2 1146 0.714141414141
# 3 1145 0.726936026936
# 4 1144 0.734006734007
# 5 1143 0.741077441077
# 6 1142 0.748148148148
# 7 1141 0.749158249158
# 8 1140 0.750168350168
# 9 1139 0.751178451178
# 10 1138 0.752188552189
# Suggested reverse clip at: 1148 (10,1138)

# %% [markdown]
# Clip Alignment using Biopython.

# %%
from Bio import AlignIO

aln = pj.fa('CytB@mafftLinsi')

clipped_aln = aln[:,forw_clip-wsize:reve_clip+wsize]
# Out:
# returning alignment object CytB@mafftLinsi

# %% [markdown]
# Convert the clipped alignemnt (which is a Biopython alignment object) to a ReproPhylo trimmed alignment object, so that we can resume working with it in ReproPhylo.

# %%
pj.trimmed_alignments["CytB@mafftLinsi_aln_clipped"] = clipped_aln

# %% [markdown]
# Write clipped alignment to file for downstream taxonomic curation using SATIVA.

# %%
from Bio import AlignIO

out=open('CytB@mafftLinsi_aln_clipped.phy', 'w')
AlignIO.write(clipped_aln, out, 'phylip-relaxed')
out.close()

# %% [markdown]
# Configure tree inference method.

# %%
raxml = RaxmlConf(pj, method_name='raxml-mafftLinsi-clipped', 
                 program_name='raxmlHPC-PTHREADS-SSE3',
                 keepfiles=True,
                 cmd='raxmlHPC-PTHREADS-SSE3',
                 preset='fa',
                 alns=['CytB@mafftLinsi_aln_clipped'],
                 model='GAMMA',
                 threads=5,
                 cline_args={'-#': 100})
# Out:
# raxmlHPC-PTHREADS-SSE3 -f a -m GTRGAMMA -n 346691473684329.62_CytB@mafftLinsi_aln_clipped0 -p 112 -s 346691473684329.62_CytB@mafftLinsi_aln_clipped.fasta -T 5 -x 209 -N 100

# %% [markdown]
# Run RaxML.

# %%
pj.tree([raxml])

# %%
print pj.used_methods['raxml-mafftLinsi-clipped']
# Out:
# RaxmlConf named raxml-mafftLinsi-clipped with ID 346691473684329.62
# Alignments: CytB@mafftLinsi_aln_clipped
# Created on: Mon Sep 12 12:45:29 2016
# Commands:
# CytB@mafftLinsi_aln_clipped:
# raxmlHPC-PTHREADS-SSE3 -f a -m GTRGAMMA -n 346691473684329.62_CytB@mafftLinsi_aln_clipped0 -p 112 -s 346691473684329.62_CytB@mafftLinsi_aln_clipped.fasta -T 5 -x 209 -N 100
#
# Environment:
# Platform: Linux-3.13.0-54-generic-x86_64-with-Ubuntu-14.04-trusty
#  Processor: x86_64
#  Python build: defaultMar 22 2014 22:59:56
#  Python compiler: GCC 4.8.2
#  Python implementation: CPython
#  Python version: 2.7.6
#  ete2 version: 2.2.1072
#  biopython version: 1.68
#  dendropy version: 3.12.2
#  cloud version: 2.8.5
#  reprophylo version 1.3
#  User: chrishah-office
#  Program and version: raxmlHPC-PTHREADS-SSE3RAxML version 8.0.12
#  Program reference: A. Stamatakis: RAxML Version 8: A tool for Phylogenetic Analysis and Post-Analysis of Large Phylogenies. In Bioinformatics
#  2014.
# execution time:
# 1936.53189111
#
# ==============================
# Core Methods section sentence:
# ==============================
# Phylogenetic trees were reconstructed from the dataset(s) CytB@mafftLinsi_aln_clipped using the program raxmlHPC-PTHREADS-SSE3RAxML version 8.0.12 [1].
#
# Reference:
# A. Stamatakis: RAxML Version 8: A tool for Phylogenetic Analysis and Post-Analysis of Large Phylogenies. In Bioinformatics, 2014.

# %%
pickle_pj(pj, 'reduced_tree.pkl')
# Out:
# 'reduced_tree.pkl'

# %% [markdown]
# Now let's visualize the tree.
#
# Prepare tree annotation:
#  - define outgroups
#  - specify support coloration

# %%
pj.add_qualifier_from_source('organism')

# %%
for species in ['Lampetra','Petromyzon']:
    pj.if_this_then_that(species, 'organism', 'outgroup', 'outgroup',
                         mode='part')

# %%
supports = {'black': [100,95],
            'dimgray': [95,75],
            'silver': [75,50]}

# %%
pj.clear_tree_annotations()
pj.annotate('.', 'outgroup', 'outgroup', 
            ['source_organism', 'record_id'], 
            node_support_dict=supports, multifurc=50, scale=500,
            html='mafftLinsi-clipped-raxml.html')

# %% [markdown]
# Create a static image of the final tree.

# %%
# %%bash
#
# last_png=$(ls -hlrt *CytB@mafftLinsi_aln_clipped.png | tail -n 1 | perl -ne 'chomp; @a=split(" "); print "$a[-1]"')
# cp $last_png CytB_mafftLinsi_clipped_raxml_dirty_multifurc50.png

# %%
pj.clear_tree_annotations()
pj.annotate('.', 'outgroup', 'outgroup', 
            ['source_organism', 'record_id'], 
            node_support_dict=supports, multifurc=None, scale=500,
            html='mafftLinsi-clipped-raxml.html')

# %%
# %%bash
#
# last_png=$(ls -hlrt *CytB@mafftLinsi_aln_clipped.png | tail -n 1 | perl -ne 'chomp; @a=split(" "); print "$a[-1]"')
# cp $last_png CytB_mafftLinsi_clipped_raxml_dirty_multifurcNone.png
